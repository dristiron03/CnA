# %%
import pandas as pd

# %%
df = pd.read_csv("Chicago_Crime_Detective.csv")
df
# Out:
# /home/dristiron/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# ...

# %%
import matplotlib.pyplot as plt

# %%
dates = []
for ind in df.index:
    dates.append(df['Date'][ind])
dates
# Out:
# ['12/31/12 23:15',
#  '12/31/12 22:00',
#  '12/31/12 22:00',
#  '12/31/12 22:00',
#  '12/31/12 21:30',
#  '12/31/12 20:30',
#  '12/31/12 20:10',
#  '12/31/12 20:00',
#  '12/31/12 19:00',
#  '12/31/12 18:00',
#  '12/31/12 18:00',
#  '12/31/12 17:00',
#  '12/31/12 16:30',
#  '12/31/12 16:20',
#  '12/31/12 16:15',
#  '12/31/12 16:00',
#  '12/31/12 16:00',
#  '12/31/12 16:00',
#  '12/31/12 14:36',
#  '12/31/12 13:45',
#  '12/31/12 13:15',
#  '12/31/12 10:00',
#  '12/31/12 9:30',
#  '12/31/12 9:00',
#  '12/31/12 8:20',
#  '12/31/12 8:05',
#  '12/31/12 7:05',
#  '12/31/12 7:00',
#  '12/31/12 7:00',
#  '12/31/12 6:50',
#  '12/31/12 5:45',
#  '12/31/12 3:00',
#  '12/31/12 3:00',
#  '12/31/12 3:00',
#  '12/31/12 2:00',
#  '12/31/12 1:00',
#  '12/31/12 0:01',
#  '12/31/12 0:00',
#  '12/31/12 0:00',
#  '12/31/12 0:00',
#  '12/30/12 23:00',
#  '12/30/12 22:30',
#  '12/30/12 22:00',
#  '12/30/12 22:00',
#  '12/30/12 21:00',
#  '12/30/12 20:00',
#  '12/30/12 20:00',
#  '12/30/12 19:46',
# ...

# %%
type(dates)
# Out:
# list

# %%
for i in range(len(dates)):
    temp = dates[i]
    x = temp.split('/')
    dates[i] = x[0]
dates
# Out:
# ['12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
# ...

# %%
import numpy as np
np_dates = np.array(dates)
unique_dates = np.unique(np_dates)
unique_dates
# Out:
# array(['1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9'],
#       dtype='<U2')

# %%
np_dates
# Out:
# array(['12', '12', '12', ..., '1', '1', '1'], dtype='<U2')

# %%
df.insert(3,'Months', np_dates)
df
# Out:
#         Unnamed: 0       ID            Date Months  \
# 0                0  8951354  12/31/12 23:15     12
# 1                1  8951141  12/31/12 22:00     12
# 2                2  8952745  12/31/12 22:00     12
# 3                3  8952223  12/31/12 22:00     12
# 4                4  8951608  12/31/12 21:30     12
# ...            ...      ...             ...    ...
# 191636      191636  1310068     1/1/01 0:05      1
# 191637      191637  1313404     1/1/01 0:01      1
# 191638      191638  1313442     1/1/01 0:01      1
# 191639      191639  1563324     1/1/01 0:01      1
# 191640      191640  1310463     1/1/01 0:01      1
#
#                   LocationDescription  Arrest  Domestic  Beat District  \
# 0                              STREET   False     False   623        6
# 1                              STREET   False     False  1213       12
# 2       RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# ...

# %%
df['Year']
# Out:
# 0         2012
# 1         2012
# 2         2012
# 3         2012
# 4         2012
#           ...
# 191636    2001
# 191637    2001
# 191638    2001
# 191639    2001
# 191640    2001
# Name: Year, Length: 191641, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191641 entries, 0 to 191640
# Data columns (total 11 columns):
# Unnamed: 0             191641 non-null int64
# ID                     191641 non-null int64
# Date                   191641 non-null object
# Months                 191641 non-null object
# LocationDescription    191641 non-null object
# Arrest                 191641 non-null bool
# Domestic               191641 non-null bool
# Beat                   191641 non-null int64
# District               148589 non-null object
# CommunityArea          167038 non-null object
# Year                   191641 non-null int64
# dtypes: bool(2), int64(4), object(5)
# memory usage: 13.5+ MB

# %%
df.groupby('Months')['Unnamed: 0'].count()
# Out:
# Months
# 1     16047
# 10    17086
# 11    16063
# 12    16426
# 2     13511
# 3     15758
# 4     15280
# 5     16035
# 6     16002
# 7     16801
# 8     16572
# 9     16060
# Name: Unnamed: 0, dtype: int64

# %%
# Lowest crime rate during February

# %%
dates = []
for ind in df.index:
    dates.append(df['Date'][ind])
dates
# Out:
# ['12/31/12 23:15',
#  '12/31/12 22:00',
#  '12/31/12 22:00',
#  '12/31/12 22:00',
#  '12/31/12 21:30',
#  '12/31/12 20:30',
#  '12/31/12 20:10',
#  '12/31/12 20:00',
#  '12/31/12 19:00',
#  '12/31/12 18:00',
#  '12/31/12 18:00',
#  '12/31/12 17:00',
#  '12/31/12 16:30',
#  '12/31/12 16:20',
#  '12/31/12 16:15',
#  '12/31/12 16:00',
#  '12/31/12 16:00',
#  '12/31/12 16:00',
#  '12/31/12 14:36',
#  '12/31/12 13:45',
#  '12/31/12 13:15',
#  '12/31/12 10:00',
#  '12/31/12 9:30',
#  '12/31/12 9:00',
#  '12/31/12 8:20',
#  '12/31/12 8:05',
#  '12/31/12 7:05',
#  '12/31/12 7:00',
#  '12/31/12 7:00',
#  '12/31/12 6:50',
#  '12/31/12 5:45',
#  '12/31/12 3:00',
#  '12/31/12 3:00',
#  '12/31/12 3:00',
#  '12/31/12 2:00',
#  '12/31/12 1:00',
#  '12/31/12 0:01',
#  '12/31/12 0:00',
#  '12/31/12 0:00',
#  '12/31/12 0:00',
#  '12/30/12 23:00',
#  '12/30/12 22:30',
#  '12/30/12 22:00',
#  '12/30/12 22:00',
#  '12/30/12 21:00',
#  '12/30/12 20:00',
#  '12/30/12 20:00',
#  '12/30/12 19:46',
# ...

# %%
total_count = 0
arrest_made = 0
for ind in range(len(df)):
    if df['Year'][ind] == 2001:
        total_count+=1
        if df['Arrest'][ind] == True:
            arrest_made += 1
print(arrest_made/total_count)
# Out:
# 0.10411727708161982

# %%
total_count = 0
arrest_made = 0
for ind in range(len(df)):
    if df['Year'][ind] == 2007:
        total_count+=1
        if df['Arrest'][ind] == True:
            arrest_made += 1
print(round((arrest_made/total_count),2))
# Out:
# 0.08

# %%
np_location = np.array(df['LocationDescription'])
unique_location = np.unique(np_location)
unique_location
# Out:
# array(['ABANDONED BUILDING',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA',
#        'AIRPORT BUILDING NON-TERMINAL - SECURE AREA',
#        'AIRPORT EXTERIOR - NON-SECURE AREA',
#        'AIRPORT EXTERIOR - SECURE AREA', 'AIRPORT PARKING LOT',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA',
#        'AIRPORT VENDING ESTABLISHMENT', 'AIRPORT/AIRCRAFT', 'ALLEY',
#        'ANIMAL HOSPITAL', 'APARTMENT', 'APPLIANCE STORE', 'ATHLETIC CLUB',
#        'BANK', 'BAR OR TAVERN', 'BARBERSHOP', 'BOWLING ALLEY', 'BRIDGE',
#        'CAR WASH', 'CHA APARTMENT', 'CHA PARKING LOT/GROUNDS',
#        'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 'CLEANING STORE',
#        'COLLEGE/UNIVERSITY GROUNDS', 'COLLEGE/UNIVERSITY RESIDENCE HALL',
#        'COMMERCIAL / BUSINESS OFFICE', 'CONSTRUCTION SITE',
#        'CONVENIENCE STORE', 'CTA GARAGE / OTHER PROPERTY', 'CTA TRAIN',
#        'CURRENCY EXCHANGE', 'DAY CARE CENTER', 'DEPARTMENT STORE',
# ...

# %%
import datetime
from datetime import date
day_names = []
for i in range(len(df)):
    year = df['Year'][i]
    month = df['Months'][i]
    day = df['Date'][i].split('/')[1]
    day_name = datetime.date(int(year), int(month), int(day))
    day_names.append(day_name.strftime("%A"))
day_names
# Out:
# ['Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Monday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
#  'Sunday',
# ...

# %%
df['day'] = day_names
df
# Out:
#         Unnamed: 0       ID            Date Months  \
# 0                0  8951354  12/31/12 23:15     12
# 1                1  8951141  12/31/12 22:00     12
# 2                2  8952745  12/31/12 22:00     12
# 3                3  8952223  12/31/12 22:00     12
# 4                4  8951608  12/31/12 21:30     12
# ...            ...      ...             ...    ...
# 191636      191636  1310068     1/1/01 0:05      1
# 191637      191637  1313404     1/1/01 0:01      1
# 191638      191638  1313442     1/1/01 0:01      1
# 191639      191639  1563324     1/1/01 0:01      1
# 191640      191640  1310463     1/1/01 0:01      1
#
#                   LocationDescription  Arrest  Domestic  Beat District  \
# 0                              STREET   False     False   623        6
# 1                              STREET   False     False  1213       12
# 2       RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# ...

# %%
df.groupby('day')['Unnamed: 0'].count()
# Out:
# day
# Friday       29284
# Monday       27397
# Saturday     27118
# Sunday       26316
# Thursday     27319
# Tuesday      26791
# Wednesday    27416
# Name: Unnamed: 0, dtype: int64

# %%
last_question = {'Monday':0, 'Tuesday':0, 'Wednesday':0, 'Thursday':0, 'Friday':0, 'Saturday':0, 'Sunday':0}
for i in range(len(df)):
    if df['LocationDescription'][i] == 'GAS STATION':
        last_question[df['day'][i]]+=1
last_question
# Out:
# {'Monday': 280,
#  'Tuesday': 270,
#  'Wednesday': 273,
#  'Thursday': 282,
#  'Friday': 332,
#  'Saturday': 338,
#  'Sunday': 336}

# %%
top_five = {}
for i in range(len(df)):
    if (df['LocationDescription'][i] not in top_five):
        top_five[df['LocationDescription'][i]] = 0
    top_five[df['LocationDescription'][i]]+=1
top_five
# Out:
# {'STREET': 156564,
#  'RESIDENTIAL YARD (FRONT/BACK)': 1536,
#  'GAS STATION': 2111,
#  'PARKING LOT/GARAGE(NON.RESID.)': 14852,
#  'VEHICLE NON-COMMERCIAL': 817,
#  'CTA GARAGE / OTHER PROPERTY': 148,
#  'RESIDENCE-GARAGE': 1176,
#  'OTHER': 4573,
#  'ALLEY': 2308,
#  'SPORTS ARENA/STADIUM': 166,
#  'VACANT LOT/LAND': 985,
#  'RESIDENCE': 1302,
#  'SCHOOL, PUBLIC, GROUNDS': 206,
#  'DRIVEWAY - RESIDENTIAL': 1675,
#  'POLICE FACILITY/VEH PARKING LOT': 266,
#  'SIDEWALK': 462,
#  'APARTMENT': 184,
#  'VEHICLE-COMMERCIAL': 23,
#  'AIRPORT VENDING ESTABLISHMENT': 10,
#  'BAR OR TAVERN': 17,
#  'PARK PROPERTY': 255,
#  'HIGHWAY/EXPRESSWAY': 22,
#  'COLLEGE/UNIVERSITY GROUNDS': 47,
#  'SMALL RETAIL STORE': 33,
#  'CAR WASH': 44,
#  'FACTORY/MANUFACTURING BUILDING': 16,
#  'RESTAURANT': 49,
#  'FIRE STATION': 5,
#  'CHA PARKING LOT/GROUNDS': 405,
#  'AIRPORT EXTERIOR - NON-SECURE AREA': 24,
#  'CTA TRAIN': 1,
#  'GROCERY FOOD STORE': 80,
#  'AIRPORT PARKING LOT': 11,
# ...

# %%
ans_top_five = sorted(top_five.items(), key=lambda x: x[1], reverse=True)

# %%
ans_top_five
# Out:
# [('STREET', 156564),
#  ('PARKING LOT/GARAGE(NON.RESID.)', 14852),
#  ('OTHER', 4573),
#  ('ALLEY', 2308),
#  ('GAS STATION', 2111),
#  ('DRIVEWAY - RESIDENTIAL', 1675),
#  ('RESIDENTIAL YARD (FRONT/BACK)', 1536),
#  ('RESIDENCE', 1302),
#  ('RESIDENCE-GARAGE', 1176),
#  ('VACANT LOT/LAND', 985),
#  ('VEHICLE NON-COMMERCIAL', 817),
#  ('SIDEWALK', 462),
#  ('CHA PARKING LOT/GROUNDS', 405),
#  ('AIRPORT/AIRCRAFT', 363),
#  ('POLICE FACILITY/VEH PARKING LOT', 266),
#  ('PARK PROPERTY', 255),
#  ('SCHOOL, PUBLIC, GROUNDS', 206),
#  ('APARTMENT', 184),
#  ('SPORTS ARENA/STADIUM', 166),
#  ('CTA GARAGE / OTHER PROPERTY', 148),
#  ('COMMERCIAL / BUSINESS OFFICE', 126),
#  ('HOTEL/MOTEL', 124),
#  ('SCHOOL, PUBLIC, BUILDING', 114),
#  ('HOSPITAL BUILDING/GROUNDS', 101),
#  ('GROCERY FOOD STORE', 80),
#  ('CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 56),
#  ('RESTAURANT', 49),
#  ('GOVERNMENT BUILDING/PROPERTY', 48),
#  ('COLLEGE/UNIVERSITY GROUNDS', 47),
#  ('CAR WASH', 44),
# ...

# %%
sum = 0
sum = ans_top_five[0][1]+ans_top_five[1][1]+ans_top_five[3][1]+ans_top_five[4][1]+ans_top_five[5][1]
sum
# Out:
# 177510

# %%
print(df['Date'][(int)(191641/2)])
# Out:
# 5/21/06 12:30

# %%
l = sorted(df['Year'], reverse = True)
# for i in range(len(df)):
#     if(l[i] != df['Year'][i]):
#         print(1)
l
# Out:
# [2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
#  2012,
# ...

# %%
fourth = {}
for i in range(len(df)):
    if (df['Months'][i] not in fourth):
        fourth[df['Months'][i]] = 0
    if df['Arrest'][i] == True:
        fourth[df['Months'][i]]+=1
fourth
# Out:
# {'12': 1397,
#  '11': 1256,
#  '10': 1342,
#  '9': 1248,
#  '8': 1329,
#  '7': 1324,
#  '6': 1230,
#  '5': 1187,
#  '4': 1252,
#  '3': 1298,
#  '2': 1238,
#  '1': 1435}

# %%
print(sorted(fourth.items(), key=lambda x: x[1], reverse=True))
# Out:
# [('1', 1435), ('12', 1397), ('10', 1342), ('8', 1329), ('7', 1324), ('3', 1298), ('11', 1256), ('4', 1252), ('9', 1248), ('2', 1238), ('6', 1230), ('5', 1187)]

# %%
first_half = 0
second_half = 0
for i in range(len(df)):
    if df['Year'][i] < 2007:
        first_half+=1
    else:
        second_half+=1
print(first_half > second_half)
# Out:
# True

# %%
# %matplotlib inline
# Seaborn for plotting and styling
import seaborn as sns

# %%
d = {}
for i in range(len(df)):
    if (df['Year'][i] not in d):
        d[df['Year'][i]] = 0
    d[df['Year'][i]]+=1
d
# Out:
# {2012: 14092,
#  2011: 15637,
#  2010: 15497,
#  2009: 12167,
#  2008: 14445,
#  2007: 14280,
#  2006: 16098,
#  2005: 16484,
#  2004: 16862,
#  2003: 16657,
#  2002: 18753,
#  2001: 20669}

# %%
lists = sorted(d.items()) # sorted by key, return a list of tuples
lists
# Out:
# [(2001, 20669),
#  (2002, 18753),
#  (2003, 16657),
#  (2004, 16862),
#  (2005, 16484),
#  (2006, 16098),
#  (2007, 14280),
#  (2008, 14445),
#  (2009, 12167),
#  (2010, 15497),
#  (2011, 15637),
#  (2012, 14092)]

# %%
# lists = sorted(d.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()
